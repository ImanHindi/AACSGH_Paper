# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load the CSV files
fileD1 = "./DDPG_Training/rolloutResult/DDPG_2.csv"  # Replace with your first CSV file path
fileD2 = "./DDPG_Training/rolloutResult/DDPG_3.csv"  # Replace with your first CSV file path

fileS1 = "C:/Users/Iman.Hindi/OneDrive - AL-Hussien bin Abdullah Technical University/Desktop/Iman/ThesisDocument/SAC_Results/SAC_Training/rolloutResult/SAC_2.csv"  # Replace with your second CSV file path
fileS2 = "C:/Users/Iman.Hindi/OneDrive - AL-Hussien bin Abdullah Technical University/Desktop/Iman/ThesisDocument/SAC_Results/SAC_Training/rolloutResult/SAC_3.csv"  # Replace with your second CSV file path
fileP1 = "C:\\Users\\Iman.Hindi\\OneDrive - AL-Hussien bin Abdullah Technical University\\Desktop\\Iman\\ThesisDocument\\result6Dec\\rolloutResult\\PPO_8(3).CSV"  # Replace with your first CSV file path
fileP2 = "C:\\Users\\Iman.Hindi\\OneDrive - AL-Hussien bin Abdullah Technical University\\Desktop\\Iman\\ThesisDocument\\result6Dec\\rolloutResult\\PPO_9(3).CSV"  # Replace with your second CSV file path
fileT1 = "C:/Users/Iman.Hindi/OneDrive - AL-Hussien bin Abdullah Technical University/Desktop/Iman/ThesisDocument/TD3_Results/TD3_Training/rolloutResult/TD3_2.csv"
fileT2 = "C:/Users/Iman.Hindi/OneDrive - AL-Hussien bin Abdullah Technical University/Desktop/Iman/ThesisDocument/TD3_Results/TD3_Training/rolloutResult/TD3_5.csv"

# Read the data into DataFrames
dfD1 = pd.read_csv(fileD1)
dfD2 = pd.read_csv(fileD2)

dfS1 = pd.read_csv(fileS1)
dfS2 = pd.read_csv(fileS2)
dfP1 = pd.read_csv(fileP1)
dfP2 = pd.read_csv(fileP2)
dfT1 = pd.read_csv(fileT1)
dfT2 = pd.read_csv(fileT2)

# Assuming the evaluation rewards are in a column named 'reward' and there is an 'episode' column
# Adjust column names as necessary to match your files
dfD1['episode'] = range(1, len(dfD1) + 1)
dfD2['episode'] = range(len(dfD1) + 1, len(dfD1) + len(dfD2) + 1)

dfS1['episode'] = range(1, len(dfS1) + 1)
dfS2['episode'] = range(len(dfS1) + 1, len(dfS1) + len(dfS2) + 1)
dfP1['episode'] = range(1, len(dfP1) + 1)
dfP2['episode'] = range(len(dfP1) + 1, len(dfP1) + len(dfP2) + 1)
dfT1['episode'] = range(1, len(dfT1) + 1)
dfT2['episode'] = range(len(dfT1) + 1, len(dfT1) + len(dfT2) + 1)
# Combine both data frames
combined_dfD = pd.concat([dfD1, dfD2], ignore_index=True)
combined_dfS = pd.concat([dfS1, dfS2], ignore_index=True)
combined_dfP = pd.concat([dfP1, dfP2], ignore_index=True)
combined_dfT = pd.concat([dfT1, dfT2], ignore_index=True)

# Plot the combined data
plt.figure(figsize=(11, 7))

plt.plot((combined_dfP['episode']*2.048)[:49], combined_dfP['Value'][:49], label='PPO')#,linestyle='-')
plt.text((combined_dfP['episode']*2.048)[48], combined_dfP['Value'][48], 'PPO', fontsize=10, color='blue')

plt.plot((combined_dfD['episode']*125)[:1150]/len(combined_dfD), combined_dfD['Value'][:1150], label='DDPG')#,linestyle='-.')
plt.text((combined_dfD['episode']*125)[1147]/len(combined_dfD), combined_dfD['Value'][1147], 'DDPG', fontsize=10, color='orange')

plt.plot((combined_dfS['episode']*135)[:1100]/len(combined_dfS), combined_dfS['Value'][:1100], label='SAC')#,linestyle='--')
plt.text((combined_dfS['episode']*135)[1097]/len(combined_dfS), combined_dfS['Value'][1097], 'SAC', fontsize=10, color='green')

plt.plot((combined_dfT['episode']*100)[:1150]/len(combined_dfT), combined_dfT['Value'][:1150], label='TD3')#,linestyle=':')
plt.text((combined_dfT['episode']*100)[1144]/len(combined_dfT), combined_dfT['Value'][1144], 'TD3', fontsize=10, color='red')

#plt.plot(combined_df_2['episode']*2.048, combined_df_2['Value'], label='With fixed weather')
plt.legend()

plt.xlabel('Thousand step')
plt.ylabel('Rollout Mean Rewards')
plt.title('Rollout Mean Rewards Over Episodes')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the combined data
plt.figure(figsize=(11, 7))
plt.plot((combined_dfP['episode']*2.048)[:49], combined_dfP['Value'][:49], linestyle='-')
plt.text((combined_dfP['episode']*2.048)[48], combined_dfP['Value'][48], 'PPO', fontsize=10, color='blue', ha='left')

plt.plot((combined_dfD['episode']*125)[:1150]/len(combined_dfD), combined_dfD['Value'][:1150], linestyle='-.')
plt.text((combined_dfD['episode']*125)[1149]/len(combined_dfD), combined_dfD['Value'][1149], 'DDPG', fontsize=10, color='orange', ha='left')

plt.plot((combined_dfS['episode']*135)[:1100]/len(combined_dfS), combined_dfS['Value'][:1100], linestyle='--')
plt.text((combined_dfS['episode']*135)[1099]/len(combined_dfS), combined_dfS['Value'][1099], 'SAC', fontsize=10, color='green', ha='left')

plt.plot((combined_dfT['episode']*100)[:1150]/len(combined_dfT), combined_dfT['Value'][:1150], linestyle=':')
plt.text((combined_dfT['episode']*100)[1140]/len(combined_dfT), combined_dfT['Value'][1140], 'TD3', fontsize=10, color='red', ha='left')

# Optional: Remove the legend since labels are at the end of each line
# plt.legend()

plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Comparison of Algorithms')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Iman.Hindi\AppData\Local\Temp\ipykernel_47524\3352897674.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = r"C:\Users\Iman.Hindi\OneDrive - AL-Hussien bin Abdullah Technical University\Desktop\Iman\ThesisDocument\PPO_Training\Training_Results\EpsReward\PPO_3.csv"  # Replace with your first CSV file path
file2 = r"C:\Users\Iman.Hindi\OneDrive - AL-Hussien bin Abdullah Technical University\Desktop\Iman\ThesisDocument\PPO_Training\Training_Results\EpsReward\PPO_4.csv"  # Replace with your second CSV file path
#file3 = "./EpsReward/PPO_6.csv"
file3 = "C:\\Users\\Iman.Hindi\\OneDrive - AL-Hussien bin Abdullah Technical University\\Desktop\\Iman\\ThesisDocument\\result6Dec\\EpsReward\\PPO_8.CSV"  # Replace with your first CSV file path
file4 = "C:\\Users\\Iman.Hindi\\OneDrive - AL-Hussien bin Abdullah Technical University\\Desktop\\Iman\\ThesisDocument\\result6Dec\\EpsReward\\PPO_9.CSV"  # Replace with your second CSV file path

#data into DataFrames
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)
df4 = pd.read_csv(file4)

# Assuming the evaluation rewards are in a column named 'reward' and there is an 'episode' column
# Adjust column names as necessary to match your files
df1['episode'] = range(1, len(df1) + 1)
df2['episode'] = range(len(df1) + 1, len(df1) + len(df2) + 1)
df3['episode'] = range(1, len(df3) + 1)
df4['episode'] = range(len(df3) + 1, len(df3) + len(df4) + 1)
# Combine both data frames
combined_df = pd.concat([df1, df2], ignore_index=True)
combined_df2 = pd.concat([df3, df4], ignore_index=True)

# Plot the combined data
plt.figure(figsize=(10, 6))
#plt.axis([0,130,0,25])
plt.plot((combined_df['episode'][:25])*10, combined_df['Value'][:25], label='With random weather')
plt.plot((combined_df2['episode'][:25])*10, combined_df2['Value'][:25], label='With fixed weather')
plt.legend()

plt.xlabel('Episode (Thousand)')
plt.ylabel('Mean Reward')
plt.title('Mean Episode Reward Over Episodes on full featured environment')
#plt.legend()
plt.grid(True)
plt.show()

# %%
file1 = r"C:\Users\Iman.Hindi\OneDrive - AL-Hussien bin Abdullah Technical University\Desktop\Iman\ThesisDocument\PPO_Training\Training_Results\train_Eplained_Varience\PPO_3.csv"  # Replace with your first CSV file path
file2 = r"C:\Users\Iman.Hindi\OneDrive - AL-Hussien bin Abdullah Technical University\Desktop\Iman\ThesisDocument\PPO_Training\Training_Results\train_Eplained_Varience\PPO_4.csv"  # Replace with your second CSV file path
#file3 = "./train_Eplained_Varience/PPO_6.csv"
file3 = "C:\\Users\\Iman.Hindi\\OneDrive - AL-Hussien bin Abdullah Technical University\\Desktop\\Iman\\ThesisDocument\\result6Dec\\train_Eplained_Varience\\PPO_8(1).CSV"  # Replace with your first CSV file path
file4 = "C:\\Users\\Iman.Hindi\\OneDrive - AL-Hussien bin Abdullah Technical University\\Desktop\\Iman\\ThesisDocument\\result6Dec\\train_Eplained_Varience\\PPO_9(1).CSV"  # Replace with your second CSV file path

#data into DataFrames
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)
df4 = pd.read_csv(file4)

# Assuming the evaluation rewards are in a column named 'reward' and there is an 'episode' column
# Adjust column names as necessary to match your files
df1['episode'] = range(1, len(df1) + 1)
df2['episode'] = range(len(df1) + 1, len(df1) + len(df2) + 1)
df3['episode'] = range(1, len(df3) + 1)
df4['episode'] = range(len(df3) + 1, len(df3) + len(df4) + 1)

# Combine both data frames
combined_df = pd.concat([df1, df2], ignore_index=True)
combined_df2 = pd.concat([df3, df4], ignore_index=True)

# Plot the combined data
plt.figure(figsize=(10, 6))
#plt.axis([0,130,0,25])
plt.plot(combined_df['episode']*2.048, combined_df['Value'], label='With random weather')
plt.plot(combined_df2['episode']*2.048, combined_df2['Value'], label='With fixed weather')
plt.legend()
plt.xlabel('Thousand Episode')
plt.ylabel('Explained Varience')
plt.title('Explained Varience Over Training Episodes')
#plt.legend()
plt.grid(True)
plt.show()

# %%
file1 = r"C:\Users\Iman.Hindi\OneDrive - AL-Hussien bin Abdullah Technical University\Desktop\Iman\ThesisDocument\PPO_Training\Training_Results\train_value_loss\PPO_3.csv"  # Replace with your first CSV file path
file2 = r"C:\Users\Iman.Hindi\OneDrive - AL-Hussien bin Abdullah Technical University\Desktop\Iman\ThesisDocument\PPO_Training\Training_Results\train_value_loss\PPO_4.csv"  # Replace with your second CSV file path
#file3 = "./train_Eplained_Varience/PPO_6.csv"
file3 = r"C:\Users\Iman.Hindi\OneDrive - AL-Hussien bin Abdullah Technical University\Desktop\Iman\ThesisDocument\result6Dec\train_value_loss\PPO_8(2).CSV"  # Replace with your first CSV file path
file4 = r"C:\Users\Iman.Hindi\OneDrive - AL-Hussien bin Abdullah Technical University\Desktop\Iman\ThesisDocument\result6Dec\train_value_loss\PPO_9(2).CSV"  # Replace with your second CSV file path

#data into DataFrames
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)
df4 = pd.read_csv(file4)

# Assuming the evaluation rewards are in a column named 'reward' and there is an 'episode' column
# Adjust column names as necessary to match your files
df1['episode'] = range(1, len(df1) + 1)
df2['episode'] = range(len(df1) + 1, len(df1) + len(df2) + 1)
df3['episode'] = range(1, len(df3) + 1)
df4['episode'] = range(len(df3) + 1, len(df3) + len(df4) + 1)

# Combine both data frames
combined_df = pd.concat([df1, df2], ignore_index=True)
combined_df2 = pd.concat([df3, df4], ignore_index=True)

# Plot the combined data
plt.figure(figsize=(10, 6))
#plt.axis([0,130,0,25])
plt.plot(combined_df['episode']*2.048, combined_df['Value'], label='With random weather')
plt.plot(combined_df2['episode']*2.048, combined_df2['Value'], label='With fixed weather')
plt.legend()
plt.xlabel('Thousand Episode')
plt.ylabel('Explained Varience')
plt.title('Explained Varience Over Training Episodes')
#plt.legend()
plt.grid(True)
plt.show()
